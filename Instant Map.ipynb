# %%
import folium 
#pip install folium
#conda install folium -c conda-forge

# %%
map = folium.Map(location=[37.7749,-122.4194])

# %%
map.save("./Source/InstantMap1.html")

# %%
import os
from IPython.display import Image
PATH = ".\\Source\\"
Image(filename = PATH+"InstantMap.jpg")
